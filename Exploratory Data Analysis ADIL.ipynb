# %% [markdown]
# # EDA (Exploratory Data Analysis) of LOAD Wine

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_wine

# %%
wine = load_wine()

df = pd.DataFrame(data=wine.data, columns= wine.feature_names)
df["target"] = wine.target
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
df.target.nunique()
# Out:
# 3

# %%
df.shape
# Out:
# (178, 14)

# %%
df.head(10)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
# 5    14.20        1.76  2.45               15.2      112.0           3.27
# 6    14.39        1.87  2.45               14.6       96.0           2.50
# 7    14.06        2.15  2.61               17.6      121.0           2.60
# 8    14.83        1.64  2.17               14.0       97.0           2.80
# 9    13.86        1.35  2.27               16.0       98.0           2.98
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# ...

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
plt.hist(df['magnesium'],bins=20)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   alcohol                       178 non-null    float64
#  1   malic_acid                    178 non-null    float64
#  2   ash                           178 non-null    float64
#  3   alcalinity_of_ash             178 non-null    float64
#  4   magnesium                     178 non-null    float64
#  5   total_phenols                 178 non-null    float64
#  6   flavanoids                    178 non-null    float64
#  7   nonflavanoid_phenols          178 non-null    float64
#  8   proanthocyanins               178 non-null    float64
#  9   color_intensity               178 non-null    float64
#  10  hue                           178 non-null    float64
#  11  od280/od315_of_diluted_wines  178 non-null    float64
# ...

# %%
#Identifying missing value in the dataframe and do the count

df.isna().sum()
# Out:
# alcohol                         0
# malic_acid                      0
# ash                             0
# alcalinity_of_ash               0
# magnesium                       0
# total_phenols                   0
# flavanoids                      0
# nonflavanoid_phenols            0
# proanthocyanins                 0
# color_intensity                 0
# hue                             0
# od280/od315_of_diluted_wines    0
# proline                         0
# target                          0
# dtype: int64

# %% [markdown]
# # Treatment of null Values

# %%
#Treatment of null values by replacing it with 0
df['alcohol'].fillna(0,inplace=True)

#Treatment of null values by replacing it with mean values
df['alcohol'].fillna(df.alcohol.mean(),inplace=True)

#Treatment of null values by droping the row
df['alcohol'].dropna()
# Out:
# 0      14.23
# 1      13.20
# 2      13.16
# 3      14.37
# 4      13.24
#        ...
# 173    13.71
# 174    13.40
# 175    13.27
# 176    13.17
# 177    14.13
# Name: alcohol, Length: 178, dtype: float64

# %%
df.rename(columns={"od280/od315_of_Diluted_wines":"Diluted_value"}, inplace = True)

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
df.target.value_counts(normalize=True)
# Out:
# 1    0.398876
# 0    0.331461
# 2    0.269663
# Name: target, dtype: float64

# %%
df.target.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print(f"Skewness : {df['magnesium'].skew()}")
print(f"Kurtosis : {df['magnesium'].kurt()}")
# Out:
# Skewness : 1.098191054755161
# Kurtosis : 2.1049913235905557

# %%
sns.catplot(x="target", y="flavanoids", data=df, kind="box")
plt.show()

# %%
sns.scatterplot(x="target", y="flavanoids", hue="target", data=df, palette="Dark2")
plt.show()

# %%
sns.scatterplot(x="proline", y="flavanoids", hue="target", data=df, palette="Dark2")
plt.show()

# %%
df_heat = df.corr()
sns.heatmap(df_heat, annot = True, cbar=True,fmt='.2f',annot_kws = {'size':7}, cmap="Spectral_r")
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics

mean = statistics.mean(df['magnesium'])
sd = statistics.stdev(df['magnesium'])
  
plt.plot(df['magnesium'], norm.pdf(df['magnesium'], mean, sd))
plt.show()

# %%
x_axis = np.arange(-20, 20, 0.01)

#calculating mean and standard deviation
mean = statistics.mean(x_axis)
sd = statistics.stdev(x_axis) 
print(sd)

plt.plot(x_axis, norm.pdf(x_axis, mean, sd)) 
plt.show()
# Out:
# 11.54844866926759
